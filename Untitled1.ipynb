# %%
import pandas as pd
import numpy as np
import sklearn
print(pd.__version__, np.__version__, sklearn.__version__)
# Out:
# 2.3.3 1.26.4 1.8.0

# %%
df=pd.read_csv("application_train.csv")

# %%
y = df['TARGET']
X = df[['EXT_SOURCE_2','NAME_EDUCATION_TYPE','NAME_INCOME_TYPE','EXT_SOURCE_3','FLAG_OWN_CAR','AMT_GOODS_PRICE','CODE_GENDER']]

# %%
df=df[['EXT_SOURCE_2','NAME_EDUCATION_TYPE','NAME_INCOME_TYPE','EXT_SOURCE_3','FLAG_OWN_CAR','AMT_GOODS_PRICE','CODE_GENDER','TARGET']]
percent=(df.isnull().sum()/df.shape[0])*100 
percent_sorted = percent.sort_values(ascending=False)
b1=[]
b2=[] 
b3=[]
b4=[]
for i in percent_sorted.index: 
    if percent_sorted[i]<5:
        b1.append(i)
    elif percent_sorted[i]>=5 and percent_sorted[i]<30:
        b2.append(i)
    elif percent_sorted[i]>=30 and percent_sorted[i]<60:
        b3.append(i) 
    elif percent_sorted[i]>=60:
        b4.append(i)

# %%
from sklearn.model_selection import train_test_split
X_reduced = X.drop(columns=b4)
X_train_r, X_test_r, y_train_r, y_test_r = train_test_split(
    X_reduced,
    y,
    stratify=y,
    random_state=42,
    train_size=0.8
)

# %%
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder,StandardScaler
cat_cols_r = X_reduced.select_dtypes(include='object').columns.tolist()
num_cols_r = X_reduced.select_dtypes(exclude='object').columns.tolist()

num_b2_r = [c for c in b2 if c in num_cols_r]
num_rest_r = [c for c in num_cols_r if c not in num_b2_r]
num_b2_pipeline_r = Pipeline([
    ('imputer', SimpleImputer(strategy='median', add_indicator=True)),
    ('scaler', StandardScaler())
])

num_rest_pipeline_r = Pipeline([
    ('imputer', SimpleImputer(strategy='median')),
    ('scaler', StandardScaler())
])

cat_pipeline_r = Pipeline([
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('ohe', OneHotEncoder(handle_unknown='ignore'))
])

# %%
from sklearn.compose import ColumnTransformer

preprocessor_r = ColumnTransformer(transformers=[
    ('num_b2', num_b2_pipeline_r, num_b2_r),
    ('num_rest', num_rest_pipeline_r, num_rest_r),
    ('cat', cat_pipeline_r, cat_cols_r)
])

# %%
xgb_clf = XGBClassifier(
    objective='binary:logistic',
    eval_metric='auc',
    tree_method='hist',
    n_jobs=-1,
    random_state=42
)

# %%
xgb_pipeline = Pipeline(steps=[
    ('preprocessing', preprocessor_r),
    ('xgb', xgb_clf)
])

# %%
param_dist = {
    'xgb__n_estimators': [200, 300, 400],
    'xgb__max_depth': [3, 4, 5, 6],
    'xgb__learning_rate': [0.05, 0.1, 0.2],
    'xgb__subsample': [0.7, 0.8, 1.0],
    'xgb__colsample_bytree': [0.7, 0.8, 1.0],
    'xgb__scale_pos_weight': [1, 3, 5]  # IMPORTANT for imbalance
}
from sklearn.model_selection import RandomizedSearchCV
random_search = RandomizedSearchCV(
    estimator=xgb_pipeline,
    param_distributions=param_dist,
    n_iter=10,                # DO NOT increase blindly
    scoring='roc_auc',
    cv=3,                     # 5 is too slow for your data
    verbose=2,
    random_state=42,
    n_jobs=1                  # IMPORTANT: avoid nested parallelism
)

# %%
random_search.fit(X_train_r, y_train_r)
# Out:
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# [CV] END xgb__colsample_bytree=1.0, xgb__learning_rate=0.1, xgb__max_depth=3, xgb__n_estimators=300, xgb__scale_pos_weight=1, xgb__subsample=1.0; total time=   2.4s
# [CV] END xgb__colsample_bytree=1.0, xgb__learning_rate=0.1, xgb__max_depth=3, xgb__n_estimators=300, xgb__scale_pos_weight=1, xgb__subsample=1.0; total time=   2.1s
# [CV] END xgb__colsample_bytree=1.0, xgb__learning_rate=0.1, xgb__max_depth=3, xgb__n_estimators=300, xgb__scale_pos_weight=1, xgb__subsample=1.0; total time=   2.3s
# [CV] END xgb__colsample_bytree=0.7, xgb__learning_rate=0.05, xgb__max_depth=5, xgb__n_estimators=300, xgb__scale_pos_weight=5, xgb__subsample=0.8; total time=   3.4s
# [CV] END xgb__colsample_bytree=0.7, xgb__learning_rate=0.05, xgb__max_depth=5, xgb__n_estimators=300, xgb__scale_pos_weight=5, xgb__subsample=0.8; total time=   3.4s
# [CV] END xgb__colsample_bytree=0.7, xgb__learning_rate=0.05, xgb__max_depth=5, xgb__n_estimators=300, xgb__scale_pos_weight=5, xgb__subsample=0.8; total time=   3.7s
# [CV] END xgb__colsample_bytree=1.0, xgb__learning_rate=0.1, xgb__max_depth=6, xgb__n_estimators=400, xgb__scale_pos_weight=1, xgb__subsample=0.7; total time=   4.3s
# [CV] END xgb__colsample_bytree=1.0, xgb__learning_rate=0.1, xgb__max_depth=6, xgb__n_estimators=400, xgb__scale_pos_weight=1, xgb__subsample=0.7; total time=   4.6s
# [CV] END xgb__colsample_bytree=1.0, xgb__learning_rate=0.1, xgb__max_depth=6, xgb__n_estimators=400, xgb__scale_pos_weight=1, xgb__subsample=0.7; total time=   4.6s
# [CV] END xgb__colsample_bytree=0.8, xgb__learning_rate=0.1, xgb__max_depth=4, xgb__n_estimators=400, xgb__scale_pos_weight=5, xgb__subsample=1.0; total time=   2.8s
# [CV] END xgb__colsample_bytree=0.8, xgb__learning_rate=0.1, xgb__max_depth=4, xgb__n_estimators=400, xgb__scale_pos_weight=5, xgb__subsample=1.0; total time=   2.9s
# [CV] END xgb__colsample_bytree=0.8, xgb__learning_rate=0.1, xgb__max_depth=4, xgb__n_estimators=400, xgb__scale_pos_weight=5, xgb__subsample=1.0; total time=   2.8s
# [CV] END xgb__colsample_bytree=0.8, xgb__learning_rate=0.2, xgb__max_depth=6, xgb__n_estimators=400, xgb__scale_pos_weight=3, xgb__subsample=1.0; total time=   3.6s
# [CV] END xgb__colsample_bytree=0.8, xgb__learning_rate=0.2, xgb__max_depth=6, xgb__n_estimators=400, xgb__scale_pos_weight=3, xgb__subsample=1.0; total time=   3.5s
# [CV] END xgb__colsample_bytree=0.8, xgb__learning_rate=0.2, xgb__max_depth=6, xgb__n_estimators=400, xgb__scale_pos_weight=3, xgb__subsample=1.0; total time=   3.5s
# [CV] END xgb__colsample_bytree=0.8, xgb__learning_rate=0.1, xgb__max_depth=6, xgb__n_estimators=400, xgb__scale_pos_weight=3, xgb__subsample=0.8; total time=   4.9s
# [CV] END xgb__colsample_bytree=0.8, xgb__learning_rate=0.1, xgb__max_depth=6, xgb__n_estimators=400, xgb__scale_pos_weight=3, xgb__subsample=0.8; total time=   4.4s
# [CV] END xgb__colsample_bytree=0.8, xgb__learning_rate=0.1, xgb__max_depth=6, xgb__n_estimators=400, xgb__scale_pos_weight=3, xgb__subsample=0.8; total time=   4.4s
# [CV] END xgb__colsample_bytree=0.7, xgb__learning_rate=0.2, xgb__max_depth=5, xgb__n_estimators=200, xgb__scale_pos_weight=5, xgb__subsample=0.8; total time=   2.4s
# [CV] END xgb__colsample_bytree=0.7, xgb__learning_rate=0.2, xgb__max_depth=5, xgb__n_estimators=200, xgb__scale_pos_weight=5, xgb__subsample=0.8; total time=   2.6s
# [CV] END xgb__colsample_bytree=0.7, xgb__learning_rate=0.2, xgb__max_depth=5, xgb__n_estimators=200, xgb__scale_pos_weight=5, xgb__subsample=0.8; total time=   2.6s
# [CV] END xgb__colsample_bytree=0.7, xgb__learning_rate=0.2, xgb__max_depth=5, xgb__n_estimators=300, xgb__scale_pos_weight=1, xgb__subsample=0.8; total time=   3.4s
# [CV] END xgb__colsample_bytree=0.7, xgb__learning_rate=0.2, xgb__max_depth=5, xgb__n_estimators=300, xgb__scale_pos_weight=1, xgb__subsample=0.8; total time=   3.3s
# [CV] END xgb__colsample_bytree=0.7, xgb__learning_rate=0.2, xgb__max_depth=5, xgb__n_estimators=300, xgb__scale_pos_weight=1, xgb__subsample=0.8; total time=   3.5s
# [CV] END xgb__colsample_bytree=1.0, xgb__learning_rate=0.2, xgb__max_depth=6, xgb__n_estimators=400, xgb__scale_pos_weight=3, xgb__subsample=0.8; total time=   4.6s
# [CV] END xgb__colsample_bytree=1.0, xgb__learning_rate=0.2, xgb__max_depth=6, xgb__n_estimators=400, xgb__scale_pos_weight=3, xgb__subsample=0.8; total time=   4.6s
# [CV] END xgb__colsample_bytree=1.0, xgb__learning_rate=0.2, xgb__max_depth=6, xgb__n_estimators=400, xgb__scale_pos_weight=3, xgb__subsample=0.8; total time=   4.7s
# [CV] END xgb__colsample_bytree=1.0, xgb__learning_rate=0.2, xgb__max_depth=3, xgb__n_estimators=400, xgb__scale_pos_weight=5, xgb__subsample=0.8; total time=   3.6s
# [CV] END xgb__colsample_bytree=1.0, xgb__learning_rate=0.2, xgb__max_depth=3, xgb__n_estimators=400, xgb__scale_pos_weight=5, xgb__subsample=0.8; total time=   3.3s
# [CV] END xgb__colsample_bytree=1.0, xgb__learning_rate=0.2, xgb__max_depth=3, xgb__n_estimators=400, xgb__scale_pos_weight=5, xgb__subsample=0.8; total time=   3.5s
# RandomizedSearchCV(cv=3,
#                    estimator=Pipeline(steps=[('preprocessing',
#                                               ColumnTransformer(transformers=[('num_b2',
#                                                                                Pipeline(steps=[('imputer',
#                                                                                                 SimpleImputer(add_indicator=True,
#                                                                                                               strategy='median')),
#                                                                                                ('scaler',
#                                                                                                 StandardScaler())]),
#                                                                                ['EXT_SOURCE_3']),
#                                                                               ('num_rest',
#                                                                                Pipeline(steps=[('imputer',
#                                                                                                 SimpleImputer(strategy='median')),
#                                                                                                ('scaler',
#                                                                                                 StandardScaler())]),
#                                                                                ['EXT_SOUR...
#                                                             multi_strategy=None,
#                                                             n_estimators=None,
#                                                             n_jobs=-1,
#                                                             num_parallel_tree=None, ...))]),
#                    n_jobs=1,
#                    param_distributions={'xgb__colsample_bytree': [0.7, 0.8,
#                                                                   1.0],
#                                         'xgb__learning_rate': [0.05, 0.1, 0.2],
#                                         'xgb__max_depth': [3, 4, 5, 6],
#                                         'xgb__n_estimators': [200, 300, 400],
#                                         'xgb__scale_pos_weight': [1, 3, 5],
#                                         'xgb__subsample': [0.7, 0.8, 1.0]},
#                    random_state=42, scoring='roc_auc', verbose=2)

# %%
best_model = random_search.best_estimator_

# %%
positive_class = 1
idx = list(best_model.classes_).index(positive_class)
y_pred_proba = best_model.predict_proba(X_test_r)[:, idx]

# %%
import numpy as np
from sklearn.metrics import classification_report 
for t in [0.3, 0.4, 0.5]:
    y_pred = (y_pred_proba >= t).astype(int)
    print(f"\nThreshold: {t}")
    print(classification_report(y_test_r, y_pred))
# Out:
# Threshold: 0.3
#               precision    recall  f1-score   support
#
#            0       0.93      0.99      0.96     56538
#            1       0.39      0.09      0.15      4965
#
#     accuracy                           0.91     61503
#    macro avg       0.66      0.54      0.55     61503
# weighted avg       0.88      0.91      0.89     61503
#
#
# Threshold: 0.4
#               precision    recall  f1-score   support
#
#            0       0.92      1.00      0.96     56538
#            1       0.48      0.03      0.06      4965
#
#     accuracy                           0.92     61503
#    macro avg       0.70      0.51      0.51     61503
# weighted avg       0.89      0.92      0.89     61503
#
#
# Threshold: 0.5
#               precision    recall  f1-score   support
#
#            0       0.92      1.00      0.96     56538
#            1       0.55      0.01      0.01      4965
#
#     accuracy                           0.92     61503
#    macro avg       0.74      0.50      0.49     61503
# weighted avg       0.89      0.92      0.88     61503

# %%
for t in [0.05, 0.1, 0.2, 0.3]:
    y_pred = (y_pred_proba >= t).astype(int)
    print(f"\nThreshold: {t}")
    print(classification_report(y_test_r, y_pred))
# Out:
# Threshold: 0.05
#               precision    recall  f1-score   support
#
#            0       0.97      0.46      0.63     56538
#            1       0.12      0.84      0.21      4965
#
#     accuracy                           0.49     61503
#    macro avg       0.55      0.65      0.42     61503
# weighted avg       0.90      0.49      0.59     61503
#
#
# Threshold: 0.1
#               precision    recall  f1-score   support
#
#            0       0.95      0.76      0.85     56538
#            1       0.18      0.58      0.27      4965
#
#     accuracy                           0.75     61503
#    macro avg       0.57      0.67      0.56     61503
# weighted avg       0.89      0.75      0.80     61503
#
#
# Threshold: 0.2
#               precision    recall  f1-score   support
#
#            0       0.93      0.95      0.94     56538
#            1       0.28      0.24      0.26      4965
#
#     accuracy                           0.89     61503
#    macro avg       0.61      0.59      0.60     61503
# weighted avg       0.88      0.89      0.89     61503
#
#
# Threshold: 0.3
#               precision    recall  f1-score   support
#
#            0       0.93      0.99      0.96     56538
#            1       0.39      0.09      0.15      4965
#
#     accuracy                           0.91     61503
#    macro avg       0.66      0.54      0.55     61503
# weighted avg       0.88      0.91      0.89     61503

# %%
from sklearn.metrics import roc_auc_score
best_model=random_search.best_estimator_
y_pred_proba_xg_best_model = best_model.predict_proba(X_test_r)[:, 1] 
roc_auc_score(y_test_r,y_pred_proba_xg_best_model)
# Out:
# 0.7376847223428978

# %%
import joblib
joblib.dump(
    best_model,
    "xgboost_credit_risk_pipeline_final.joblib"
)
# Out:
# ['xgboost_credit_risk_pipeline_final.joblib']

# %%
loaded_model=joblib.load('xgboost_credit_risk_pipeline.joblib')

# %%
loaded_model.named_steps['preprocessing'].feature_names_in_
# Out:
# array(['EXT_SOURCE_2', 'NAME_EDUCATION_TYPE', 'NAME_INCOME_TYPE',
#        'EXT_SOURCE_3', 'FLAG_OWN_CAR', 'AMT_GOODS_PRICE', 'CODE_GENDER'],
#       dtype=object)

# %%
import xgboost
import streamlit
print('sklearn',sklearn.__version__)
print('numpy',np.__version__)
print('pandas',pd.__version__)
print('xgboost',xgboost.__version__)
print('joblib',joblib.__version__)  
print('streamlit',streamlit.__version__)
# Out:
# sklearn 1.8.0
# numpy 1.26.4
# pandas 2.3.3
# xgboost 3.1.2
# joblib 1.5.3
# streamlit 1.52.2
